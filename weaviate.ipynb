# %% [markdown]
# <a href="https://colab.research.google.com/github/ramaraweera/introduction-to-ai-native-vector-databases-4470531/blob/main/weaviate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==0.28.0 weaviate-client langchain langchain-community pypdf
# Out:
# Collecting openai==0.28.0
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Collecting weaviate-client
#   Downloading weaviate_client-4.18.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.0.8)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pypdf
#   Downloading pypdf-6.4.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from openai==0.28.0) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai==0.28.0) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from openai==0.28.0) (3.13.2)
# Requirement already satisfied: httpx<0.29.0,>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from weaviate-client) (0.28.1)
# Collecting validators<1.0.0,>=0.34.0 (from weaviate-client)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: authlib<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from weaviate-client) (1.6.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from weaviate-client) (2.11.10)
# Requirement already satisfied: grpcio<1.80.0,>=1.59.5 in /usr/local/lib/python3.12/dist-packages (from weaviate-client) (1.76.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.21.6 in /usr/local/lib/python3.12/dist-packages (from weaviate-client) (5.29.5)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from weaviate-client) (2.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.0.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.0.3)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.44)
# Collecting requests>=2.20 (from openai==0.28.0)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.45)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28.0) (1.22.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib<2.0.0,>=1.2.1->weaviate-client) (43.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from deprecation<3.0.0,>=2.1.0->weaviate-client) (25.0)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<1.80.0,>=1.59.5->weaviate-client) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<0.29.0,>=0.26.0->weaviate-client) (0.16.0)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (1.33)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28.0) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<0.29.0,>=0.26.0->weaviate-client) (1.3.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib<2.0.0,>=1.2.1->weaviate-client) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.2.1->weaviate-client) (2.23)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 4.9 MB/s eta 0:00:00
# Downloading weaviate_client-4.18.1-py3-none-any.whl (598 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.1/598.1 kB 20.1 MB/s eta 0:00:00
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 42.2 MB/s eta 0:00:00
# Downloading pypdf-6.4.0-py3-none-any.whl (329 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.5/329.5 kB 11.9 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.2 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 3.8 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 1.8 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 1.6 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: validators, requests, pypdf, mypy-extensions, marshmallow, typing-inspect, openai, dataclasses-json, weaviate-client, langchain-text-splitters, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: openai
#     Found existing installation: openai 2.8.1
#     Uninstalling openai-2.8.1:
#       Successfully uninstalled openai-2.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 langchain-classic-1.0.0 langchain-community-0.4.1 langchain-text-splitters-1.0.0 marshmallow-3.26.1 mypy-extensions-1.1.0 openai-0.28.0 pypdf-6.4.0 requests-2.32.5 typing-inspect-0.9.0 validators-0.35.0 weaviate-client-4.18.1

# %%
from IPython.display import HTML, display

def set_css():
    display(HTML('''
    <style>
    pre {
        white-space: pre-wrap;
    }
    </style>
    '''))

get_ipython().events.register('pre_run_cell', set_css)

# %%
import openai
import os
from google.colab import userdata
from typing import List, Optional
import weaviate
import datetime
import json
from weaviate.auth import Auth
from weaviate.util import generate_uuid5
from weaviate.classes.query import Filter
import weaviate.classes as wvc
from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader, TextLoader, UnstructuredURLLoader
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
def call_gpt4(system_prompt, user_prompt, chunks=None):
    openai.api_key = os.getenv("OPENAI_API_KEY", userdata.get('OPENAI_API_KEY'))
    if not openai.api_key:
        raise ValueError("OpenAI API key not found. Set the OPENAI_API_KEY environment variable.")

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

    # Add chunks if provided
    if chunks:
        all_chunks = "---------\n".join(chunks)
        messages.append({"role": "system", "content": f"Use the following context to answer the question <Context>{all_chunks}</Context>"})

    print(json.dumps(messages, indent=4))
    response = openai.ChatCompletion.create(
        model="gpt-4-1106-preview",
        messages=messages
    )
    return response['choices'][0]['message']['content']
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
def init_pdf_collection(client: weaviate.Client, collection_name: str) -> None:
    documents = client.collections.delete(collection_name)

    documents= client.collections.create(
        name=collection_name,
        vectorizer_config=wvc.config.Configure.Vectorizer.text2vec_openai(),    # Set the vectorizer to "text2vec-openai" to use the OpenAI API for vector-related operations
        # https://weaviate.io/developers/weaviate/config-refs/datatypes
        properties=[
            wvc.config.Property(
                name="content",
                data_type=wvc.config.DataType.TEXT,
                vectorize_property_name=True,
                tokenization=wvc.config.Tokenization.LOWERCASE
            ),
            wvc.config.Property(
                name="date",
                data_type=wvc.config.DataType.DATE,
                vectorize_property_name=False  # Include the property name ("question") when vectorizin
            ),
            wvc.config.Property(
                name="page_number",
                data_type=wvc.config.DataType.INT,
                vectorize_property_name=False  # Include the property name ("question") when vectorizin
            ),
            wvc.config.Property(
                name="total_pages",
                data_type=wvc.config.DataType.INT,
                vectorize_property_name=False  # Include the property name ("question") when vectorizin
            ),
            wvc.config.Property(
                name="file_path",
                data_type=wvc.config.DataType.TEXT,
                vectorize_property_name=True  # Include the property name ("question") when vectorizin
            ),
            wvc.config.Property(
                name="chunk_number",
                data_type=wvc.config.DataType.INT,
                vectorize_property_name=False  # Include the property name ("question") when vectorizin
            ),
            wvc.config.Property(
                name="total_chunks",
                data_type=wvc.config.DataType.INT,
                vectorize_property_name=False  # Include the property name ("question") when vectorizin
            )

            # https://weaviate.io/developers/weaviate/config-refs/datatypes
        ]
    )
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
def ingest(file_path, collection):
    # Define the file path and metadata

    # Process the PDF file asynchronously
    documents = load_pdf(file_path)

    # Output the processed documents
    for i,doc in enumerate(documents):
        pagenumber = i
        chunks = chunk_text(doc.page_content)
        # Store chunks in Weaviate
        for j,chunk in enumerate(chunks):
            print(f'Processing {file_path} page {i+1} chunk {j+1} of {len(chunks)}')
            data_object = {
                "date": datetime.datetime.now().strftime("%Y-%m-%dT%H:%M:%S.%fZ"),
                "content": chunk,
                "page_number": pagenumber,
                "file_path": file_path,
                "total_pages": len(documents),
                "chunk_number": j,
                "total_chunks": len(chunks)
            }
            collection.data.insert(data_object)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
def get_weaviate_client() -> weaviate.Client:
    """
    Get a Weaviate client instance.

    Returns:
        weaviate.Client: The Weaviate client instance
    """
    weaviate_url = userdata.get('WEAVIATE_URL')
    api_key = userdata.get('WEAVIATE_API_KEY')
    openai_key = userdata.get('OPENAI_API_KEY')

    client = weaviate.connect_to_weaviate_cloud(
                    cluster_url=weaviate_url,
                    auth_credentials=Auth.api_key(api_key),
                    headers={'X-OpenAI-Api-key': openai_key}
                )
    return client
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
def load_pdf(file_path: str) -> list:
    """
    load a pdf into a list of pages / documents

    Args:
        file_path: HTTPS URL to PDF file

    Returns:
        list: Processed documents

    Raises:
        ValueError: If URL does not use HTTPS protocol
    """

    try:
        loader = PyPDFLoader(file_path)
        # documentS because the single document is split into multiple documents
        documents = loader.load()

        return documents

    finally:
        if 'temp_path' in locals():
            os.unlink(temp_path)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
def chunk_text(text: str, chunk_size: int = 1000, overlap: int = 100) -> List[str]:
    """
    Splits text into overlapping chunks of specified size.

    Args:
        text (str): The input text to be chunked
        chunk_size (int): Maximum size of each chunk in characters
        overlap (int): Number of characters to overlap between chunks

    Returns:
        List[str]: List of text chunks
    """
    # ... keeping the same chunking logic from wvsearch.py ...
    chunks = []
    start = 0
    text_length = len(text)

    while start < text_length:
        end = start + chunk_size

        if end < text_length:
            next_period = text.find('.', end - 50, end + 50)
            if next_period != -1:
                end = next_period + 1
            else:
                next_space = text.find(' ', end)
                if next_space != -1:
                    end = next_space

        chunks.append(text[start:end].strip())
        start = end - overlap

    return chunks
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
def search_weaviate(**kwargs):
    """
    Search for documents using the vector store.

    Args:
        **kwargs: Keyword arguments
            search_term (str): The search query text
            metadata_filter (dict, optional): Dictionary of metadata key-value pairs to filter results
            limit (int, optional): Maximum number of results to return (default: 10)

    Returns:
        list: List of search results with content and metadata
    """
    search_term = kwargs.get('search_term')
    limit = kwargs.get('limit', 10)
    collection = kwargs.get('collection')
    file_path = kwargs.get('file_path')

    results = collection.query.near_text(
        query=search_term,
        limit=10,
        filters=Filter.by_property("file_path").equal(file_path)
    )
    return results
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
llmtest = call_gpt4("You are a helpful assistant.", "According to the Hitch Hikers Guide to the galaxy. What is the Answer to everything?")
print(llmtest)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
# [
#     {
#         "role": "system",
#         "content": "You are a helpful assistant."
#     },
#     {
#         "role": "user",
#         "content": "According to the Hitch Hikers Guide to the galaxy. What is the Answer to everything?"
#     }
# ]
# According to Douglas Adams' science fiction series "The Hitchhiker's Guide to the Galaxy," the Answer to the Ultimate Question of Life, the Universe, and Everything is simply the number 42. This enigmatic and humorous answer is provided by an advanced supercomputer named Deep Thought after seven and a half million years of computation. However, the actual Ultimate Question itself is unknown, which prompts further comedic exploration in the story.

# %%
wclient = get_weaviate_client()
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
collection_name="pdf"
init_pdf_collection(wclient, collection_name)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
collection = wclient.collections.get(collection_name)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
file_path = "/content/sample_data/Promoga Help CenterFAQ.pdf"
ingest(file_path, collection)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 1 chunk 1 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 1 chunk 2 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 2 chunk 1 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 2 chunk 2 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 3 chunk 1 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 3 chunk 2 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 4 chunk 1 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 4 chunk 2 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 5 chunk 1 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 5 chunk 2 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 6 chunk 1 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 6 chunk 2 of 2
# Processing /content/sample_data/Promoga Help CenterFAQ.pdf page 7 chunk 1 of 1

# %%
results = search_weaviate(search_term="How can I get a refund?", collection=collection, file_path=file_path)
llm_chunks=[]
if results:
    for i, chunk in enumerate(results.objects):
      print(chunk.properties.get('content'))
      llm_chunks.append(chunk.properties.get('content'))
      print('----------------------------------')
else:
    print("No results found.")
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
# mation. Sometimes, receipts might be delayed due
# to heavy site traffic; please allow up to 24 hours. You can check your purchase information in
# My Purchases or manage your reservations under My Reservations.
# What happens if the instructor or organizer cancels my
# activity?
# If you’re notified of a cancellation, contact the instructor via My Purchases > Options >
# Message Instructor from the profile drop-down.
# ----------------------------------
# Term-plans-limited-features
# If the instructor chooses to offer term passes (30 day, 3, 6, or 12 months), the bookings and
# reservation rules are the sole responsibility of the instructor. Currently, Promoga does not
# provide tracking and reservations for term pricing passes sold on Promoga. As noted in
# section 3 of the My Studio page, term passes sold should be tracked by the instructor.
# Payments and Charges
# What debit/credit cards do you accept?
# We accept Visa, Mastercard, Visa & MC debit, and Amex.
# Can I cancel a class I have paid for?
# Yes, you can cancel your purchase up to 48 hours after payment, but no later than 48 hours
# before the class. For free purchases, cancellation is permitted up to 24 hours before the
# reserved session. Visit My Purchases to cancel where appropriate. For more, see “Terms of
# Use” at the website footer.
# What are the fees for an activity I sell on Promoga?
# Total fees include:
#  A payout fee for the instructor/organizer,
#  A Stripe credit card transaction fee,
# 
# ----------------------------------
# What happens if my activity is full or sold out?
# If the activity is full or sold out, you cannot create new listings for it. The activity will no longer
# appear on Promoga for new students.
# Would the drop-in session pass be valid if I create a new
# series listing for an existing activity?
# Your drop-in session for this activity will not be affected as long as the activity is not full.
# Can I edit a published activity?
# You can edit an activity at any time from Instructor’s Activities menu → edit activity, However, if
# at least one student is enrolled, changes to the title, format (online/on-site/hybrid),
# schedule, or terms are not allowed.
# If you need to make an edit for an activity with enrolled students, you may unpublish the activity
# and create a new one. We recommend messaging any currently enrolled students about the
# changes from the Instructor’s Activities menu and issuing refunds via Stripe if necessary.
# Where can I edit my zoom or google meet link to teach an
# online activity?
# You
# ----------------------------------
# a Stripe if necessary.
# Where can I edit my zoom or google meet link to teach an
# online activity?
# You can edit your zoom or google meet link via Instructor’s Activities menu → edit activity.
# Where can I edit my schedule to teach?
# You can edit your listing’s schedule via Instructor’s Activities menu → edit activity. However, if at
# least one student is enrolled, changes to the title, format (online/on-site/hybrid), schedule,
# or terms are not allowed.
# Where can I find wording for my waiver for the activity I
# create as an instructor?
# We recommend that you consult a legal source to draft your waiver.
# ----------------------------------
# 2. Tap the three-dot menu top right.
# 3. Select Settings > Site settings > Notifications.
# 4. Choose the website and toggle “Allow notifications”.
# Safari:
# 1. Open Settings on your device.
# 2. Scroll to Safari > Websites > Notifications.
# 3. Select the website, then choose “Allow Notifications”, “Ask”, or “Block”.
# Manage Accounts
# How do I unsubscribe from emails?
# Instructions for unsubscribing are found in the email footer and within your account settings.
# How do I delete my account?
# We’d be sad to see you go! Try searching for new activities you might enjoy. If you'd still like to
# leave:
#  Go to the site header, find Accounts > Account Access, and follow the instructions to delete
# your account.
# How do I reset my password?
# Go to Accounts > Account Access in the site header to reset your password.
# How do I embed the scheduler into my website?
# This feature is available for instructors with an existing studio website.
#  Go to My Studios Space > Select your studio > Edit > scroll to section #4 Studio
# Scheduler Plugin.
# ----------------------------------
# fees include:
#  A payout fee for the instructor/organizer,
#  A Stripe credit card transaction fee,
#  Promoga’s service fee,
#  Government tax on the Promoga service fee.
# You can check the Stripe fee by visiting their pricing page.
# Where can I see the number of registered students for my
# listings?
# You can view the number of students registered by clicking the dropdown for the specific activity
# in Instructor's Activities in the top right menu.
# ----------------------------------
# What is a hybrid activity?
# A hybrid activity allows students to choose to attend either online (via Zoom) or in-person. You
# must select your preference during registration.
# Where can I find the Zoom or Google meet link for an
# online activity?
# Your Zoom or Google meet link will be enabled 10 minutes before the activity begins. It is
# displayed with the activity in the My Reservations page.
# After joining a hybrid activity (online or onsite), can I
# switch my chosen channel?
# No. However, you may cancel your pass (subject to the cancellation policy) and purchase a new
# pass with your desired channel.
# Where can I see who joined the activity I created as an
# instructor?
# You can see the students who joined your class (attendees) by clicking on the Instructor’s
# Schedule from the top right menu.
# How do I contact my instructor?
# After joining the activity, go to your mobile browser and use the messaging icon on the bottom
# right to send a direct or group message to your instructor.
# ----------------------------------
# Do I need to have a waiver for the activity I create?
# No, it’s not mandatory—but it is recommended. Be sure to get legal advice before publishing
# your waiver. As stated in Promoga’s Terms of Use, the waiver is the responsibility of the
# activity creator.
# Does a student have to sign the waiver before joining my
# activity?
# Yes. If your activity has a waiver, the student must sign it before joining.
# Do I have access to a report showing a student has
# signed my waiver?
# Yes, this is possible on a case-by-case basis.
# Which online platforms can I use to teach an online
# activity?
# Currently, you can use Zoom or Google Meet links to teach online. You’ll need a valid
# Zoom/Google account and the appropriate plan. The instructor is responsible for ensuring the
# validity of the published link.
# Join Activities
# What happens after I sign up for a class?
# After signing up, you'll receive an email confirmation. Sometimes, receipts might be delayed due
# to heavy site traffic; please allow up to 24 hours.
# ----------------------------------
# What is your privacy policy?
# You can read our privacy policy at https://promoga.com/privacy
# What is your terms of use?
# You can read our terms of use at https://promoga.com/terms-of-use
# ----------------------------------
# essage your attendees:
#  On a mobile browser, after logging in, use the messaging icon on the bottom right to
# start a group chat or direct message.
#  Alternatively, go to the instructor’s activities menu as described above.
# How do I create a new session pass for an existing
# activity where the available number of sessions have
# expired (provided the activity is not full)?
# If the remaining classes in a series are not full, go to the relevant activity under the Instructor’s
# Activities menu and click “Create a new session listing.” Fill in the necessary information and
# publish the new session pass.
# ----------------------------------

# %%
answer = call_gpt4("You are a helpful assistant.", "How can I get a refund?",llm_chunks)
print('')
print("LLMS ANSWER -------------------")
print(answer)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
# [
#     {
#         "role": "system",
#         "content": "You are a helpful assistant."
#     },
#     {
#         "role": "user",
#         "content": "How can I get a refund?"
#     },
#     {
#         "role": "system",
#         "content": "Use the following context to answer the question <Context>mation. Sometimes, receipts might be delayed due\nto heavy site traffic; please allow up to 24 hours. You can check your purchase information in \nMy Purchases or manage your reservations under My Reservations.\nWhat happens if the instructor or organizer cancels my \nactivity?\nIf you\u2019re notified of a cancellation, contact the instructor via My Purchases > Options > \nMessage Instructor from the profile drop-down.---------\nTerm-plans-limited-features\nIf the instructor chooses to offer term passes (30 day, 3, 6, or 12 months), the bookings and \nreservation rules are the sole responsibility of the instructor. Currently, Promoga does not \nprovide tracking and reservations for term pricing passes sold on Promoga. As noted in \nsection 3 of the My Studio page, term passes sold should be tracked by the instructor.\nPayments and Charges\nWhat debit/credit cards do you accept?\nWe accept Visa, Mastercard, Visa & MC debit, and Amex.\nCan I cancel a class I have paid for?\nYes, you can cancel your purchase up to 48 hours after payment, but no later than 48 hours \nbefore the class. For free purchases, cancellation is permitted up to 24 hours before the \nreserved session. Visit My Purchases to cancel where appropriate. For more, see \u201cTerms of \nUse\u201d at the website footer.\nWhat are the fees for an activity I sell on Promoga?\nTotal fees include:\n\uf06c A payout fee for the instructor/organizer,\n\uf06c A Stripe credit card transaction fee,\n\uf06c---------\nWhat happens if my activity is full or sold out?\nIf the activity is full or sold out, you cannot create new listings for it. The activity will no longer \nappear on Promoga for new students.\nWould the drop-in session pass be valid if I create a new \nseries listing for an existing activity?\nYour drop-in session for this activity will not be affected as long as the activity is not full.\nCan I edit a published activity?\nYou can edit an activity at any time from Instructor\u2019s Activities menu \u2192 edit activity, However, if \nat least one student is enrolled, changes to the title, format (online/on-site/hybrid), \nschedule, or terms are not allowed.\nIf you need to make an edit for an activity with enrolled students, you may unpublish the activity \nand create a new one. We recommend messaging any currently enrolled students about the \nchanges from the Instructor\u2019s Activities menu and issuing refunds via Stripe if necessary.\nWhere can I edit my zoom or google meet link to teach an\nonline activity?\nYou---------\na Stripe if necessary.\nWhere can I edit my zoom or google meet link to teach an\nonline activity?\nYou can edit your zoom or google meet link via Instructor\u2019s Activities menu \u2192 edit activity.\nWhere can I edit my schedule to teach?\nYou can edit your listing\u2019s schedule via Instructor\u2019s Activities menu \u2192 edit activity. However, if at \nleast one student is enrolled, changes to the title, format (online/on-site/hybrid), schedule, \nor terms are not allowed.\nWhere can I find wording for my waiver for the activity I \ncreate as an instructor?\nWe recommend that you consult a legal source to draft your waiver.---------\n2. Tap the three-dot menu top right.\n3. Select Settings > Site settings > Notifications.\n4. Choose the website and toggle \u201cAllow notifications\u201d.\nSafari:\n1. Open Settings on your device.\n2. Scroll to Safari > Websites > Notifications.\n3. Select the website, then choose \u201cAllow Notifications\u201d, \u201cAsk\u201d, or \u201cBlock\u201d.\nManage Accounts\nHow do I unsubscribe from emails?\nInstructions for unsubscribing are found in the email footer and within your account settings.\nHow do I delete my account?\nWe\u2019d be sad to see you go! Try searching for new activities you might enjoy. If you'd still like to \nleave:\n Go to the site header, find Accounts > Account Access, and follow the instructions to ...
#     }
# ]
#
# LLMS ANSWER -------------------
# Based on the context provided, here is how you can typically request a refund for an activity or class you've paid for on Promoga:
#
# 1. Go to "My Purchases" on the Promoga platform.
# 2. Look for the option to cancel your reservation or purchase. You are allowed to cancel up to 48 hours after payment, but no later than 48 hours before the class starts.
# 3. Once you find the purchase you would like to refund, there should be an option there to cancel it. Follow the cancellation procedures outlined on the site.
#
# In case of any difficulties or lack of clarity, you might want to check the "Terms of Use" at the website footer for more detailed instructions on the refund policy. If the terms state that refunds are issued via Stripe, and you've followed the cancellation policy correctly, then the refund will be processed through Stripe to the debit/credit card you used for payment.
#
# If your activity was canceled by the instructor or organizer, or there are special circumstances, you may need to contact the instructor directly through the messaging feature provided on the site ("Message Instructor" from the profile drop-down in "My Purchases" > Options).
#
# For any further assistance or clarification, it would be advisable to get in touch with Promoga's customer service or follow any specific instructions provided within the platform on obtaining a refund.

# %%
wclient.close()
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
